# %%
# %sql
select * from dev.bronze.products_raw

# %%
# %sql
CREATE TABLE IF NOT EXISTS dev.silver.products_scd2 (
    product_id INT,
    product_name STRING,
    category STRING,
    price DECIMAL(10,2),
    supplier_id INT,
    ingestion_date DATE,
    effective_date DATE,
    end_date DATE,
    is_current BOOLEAN,
    version INT
)
